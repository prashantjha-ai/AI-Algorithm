# %% [markdown]
# # Exercise #1
# # Name : Prashant Kumar Jha
# # Student ID: 100860548

# %% [markdown]
# # 1. Download a sports dataset (Cricket, NHL, NBA, MLB ...)  from Kaggle (or any other public repository)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/prashant-devops/AI-Algorithm/main/IPL%20Matches%202008-2020.csv')
data
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# # 2. Do a comprehensive EDA on the dataset

# %%
print(data.head())
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
# Get basic information about the dataset
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
print(data.isnull().sum())
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
print(data.dtypes)
# Out:
# id                   int64
# city                object
# date                object
# player_of_match     object
# venue               object
# neutral_venue        int64
# team1               object
# team2               object
# toss_winner         object
# toss_decision       object
# winner              object
# result              object
# result_margin      float64
# eliminator          object
# method              object
# umpire1             object
# umpire2             object
# dtype: object

# %% [markdown]
# # 3. Findings

# %% [markdown]
# ## Number of matches played by each team

# %%
data["date"] = pd.to_datetime(data["date"])

# Creating new column year the dates
data["Year"] = data["date"].dt.year
# Creating new column month the dates
data["Month"] = data["date"].dt.month

# Creating new column day the dates
data["Day"] = data["date"].dt.day

# Creating new column weekday the dates
data["Weekday"] = data["date"].dt.weekday

# %%
# Creating the variable list as matches and converting that into Series
matches = list(data["team1"]) + list(data["team2"])
matches = pd.Series(matches)

matches_df = pd.DataFrame(matches)

# Number of matches played by each team
matches.value_counts().sort_values(ascending = False)

plt.figure(figsize=(15,4))
sns.histplot(matches)
plt.xticks(rotation = 89)
plt.xlabel("Teams", fontsize = 14)
plt.ylabel("Number of matches", fontsize = 14)
plt.title("Number of matches played by each team", fontsize = 14)
plt.show()

# %% [markdown]
# ## Numbers of matches won by each team

# %%
data.winner.value_counts()

sns.barplot( x = data.winner.value_counts(), y = data.winner.value_counts().index)
plt.xlabel("Number of wins", fontsize = 14)
plt.ylabel("Teams",fontsize = 14)
plt.title("Matches won by each team", fontsize = 14)
plt.show()

# %% [markdown]
# ## Team's winning percentage for each Year

# %%
for i in data.Year.unique():
  print("*********  Year :", i,"  *********")
  plt.pie(data[data["Year"]== i]["winner"].value_counts(), autopct = "%1.1f%%")
  plt.legend(data[data["Year"]== i]["winner"].value_counts().index, bbox_to_anchor = (1,1),title='Teams in {}'.format(i) ) # The bbox_to_anchor argument is used to specify the precise placement of the legend.
  plt.show()
# Out:
# *********  Year : 2008   *********
# *********  Year : 2009   *********
# *********  Year : 2010   *********
# *********  Year : 2011   *********
# *********  Year : 2012   *********
# *********  Year : 2013   *********
# *********  Year : 2014   *********
# *********  Year : 2015   *********
# *********  Year : 2016   *********
# *********  Year : 2017   *********
# *********  Year : 2018   *********
# *********  Year : 2019   *********
# *********  Year : 2020   *********
